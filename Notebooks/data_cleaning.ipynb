# %%
###

# %% [markdown]
# #### Installing Libraries

# %%
# !pip install GEOparse
# Out:
# Collecting GEOparse
#   Downloading GEOparse-2.0.3.tar.gz (278 kB)
#      |████████████████████████████████| 278 kB 733 kB/s eta 0:00:01
# Requirement already satisfied: numpy>=1.7 in /home/kousik/.local/lib/python3.8/site-packages (from GEOparse) (1.18.1)
# Requirement already satisfied: pandas>=0.17 in /home/kousik/.local/lib/python3.8/site-packages (from GEOparse) (1.2.4)
# Requirement already satisfied: requests>=2.21.0 in /usr/lib/python3/dist-packages (from GEOparse) (2.22.0)
# Requirement already satisfied: tqdm>=4.31.1 in /home/kousik/.local/lib/python3.8/site-packages (from GEOparse) (4.62.2)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/lib/python3/dist-packages (from pandas>=0.17->GEOparse) (2.7.3)
# Requirement already satisfied: pytz>=2017.3 in /usr/lib/python3/dist-packages (from pandas>=0.17->GEOparse) (2019.3)
# Building wheels for collected packages: GEOparse
#   Building wheel for GEOparse (setup.py) ... done
#   Created wheel for GEOparse: filename=GEOparse-2.0.3-py3-none-any.whl size=29030 sha256=8642d58fb634d2bed4229e7335867c8b8175ef7dad74e45e06db5bdeb872da45
#   Stored in directory: /home/kousik/.cache/pip/wheels/7a/75/14/727a857e321c5e5590d7e58efe9f028d753d340cea4ee540f0
# Successfully built GEOparse
# Installing collected packages: GEOparse
# Successfully installed GEOparse-2.0.3

# %% [markdown]
# #### Importing Libraries

# %%
import GEOparse
import pandas as pd

# %% [markdown]
# #### Loading Data

# %%
gse = GEOparse.get_GEO(filepath="./GSE7390_family.soft.gz",silent=True,)

# %%
gse.gpls['GPL96'].table#.items()
# Out:
#                     ID  GB_ACC    SPOT_ID Species Scientific Name  \
# 0            1007_s_at  U48705        NaN            Homo sapiens
# 1              1053_at  M87338        NaN            Homo sapiens
# 2               117_at  X51757        NaN            Homo sapiens
# 3               121_at  X69699        NaN            Homo sapiens
# 4            1255_g_at  L36861        NaN            Homo sapiens
# ...                ...     ...        ...                     ...
# 22278   AFFX-ThrX-5_at     NaN  --Control            Homo sapiens
# 22279   AFFX-ThrX-M_at     NaN  --Control            Homo sapiens
# 22280  AFFX-TrpnX-3_at     NaN  --Control            Homo sapiens
# 22281  AFFX-TrpnX-5_at     NaN  --Control            Homo sapiens
# 22282  AFFX-TrpnX-M_at     NaN  --Control            Homo sapiens
#
#       Annotation Date      Sequence Type                  Sequence Source  \
# 0         Oct 6, 2014  Exemplar sequence  Affymetrix Proprietary Database
# 1         Oct 6, 2014  Exemplar sequence                          GenBank
# 2         Oct 6, 2014  Exemplar sequence  Affymetrix Proprietary Database
# 3         Oct 6, 2014  Exemplar sequence                          GenBank
# 4         Oct 6, 2014  Exemplar sequence  Affymetrix Proprietary Database
# ...               ...                ...                              ...
# 22278     Oct 6, 2014   Control sequence  Affymetrix Proprietary Database
# 22279     Oct 6, 2014   Control sequence  Affymetrix Proprietary Database
# 22280     Oct 6, 2014   Control sequence  Affymetrix Proprietary Database
# 22281     Oct 6, 2014   Control sequence  Affymetrix Proprietary Database
# 22282     Oct 6, 2014   Control sequence  Affymetrix Proprietary Database
#
#                                       Target Description  \
# 0      U48705 /FEATURE=mRNA /DEFINITION=HSU48705 Huma...
# 1      M87338 /FEATURE= /DEFINITION=HUMA1SBU Human re...
# 2      X51757 /FEATURE=cds /DEFINITION=HSP70B Human h...
# 3      X69699 /FEATURE= /DEFINITION=HSPAX8A H.sapiens...
# 4      L36861 /FEATURE=expanded_cds /DEFINITION=HUMGC...
# ...                                                  ...
# 22278  B. subtilis /GEN=thrC /DB_XREF=gb:X04603.1 /NO...
# 22279  B. subtilis /GEN=thrC, thrB /DB_XREF=gb:X04603...
# 22280  B. subtilis /GEN=trpC, trpF /DB_XREF=gb:K01391...
# 22281  B. subtilis /GEN=trpE, trpD /DB_XREF=gb:K01391...
# 22282  B. subtilis /GEN=trpD, trpC /DB_XREF=gb:K01391...
#
#       Representative Public ID  \
# 0                       U48705
# 1                       M87338
# 2                       X51757
# 3                       X69699
# 4                       L36861
# ...                        ...
# 22278              AFFX-ThrX-5
# 22279              AFFX-ThrX-M
# 22280             AFFX-TrpnX-3
# 22281             AFFX-TrpnX-5
# 22282             AFFX-TrpnX-M
#
#                                               Gene Title       Gene Symbol  \
# 0      discoidin domain receptor tyrosine kinase 1 //...  DDR1 /// MIR4640
# 1            replication factor C (activator 1) 2, 40kDa              RFC2
# 2                   heat shock 70kDa protein 6 (HSP70B')             HSPA6
# 3                                           paired box 8              PAX8
# 4                guanylate cyclase activator 1A (retina)            GUCA1A
# ...                                                  ...               ...
# 22278                                                NaN               NaN
# 22279                                                NaN               NaN
# 22280                                                NaN               NaN
# 22281                                                NaN               NaN
# 22282                                                NaN               NaN
#
#           ENTREZ_GENE_ID                               RefSeq Transcript ID  \
# 0      780 /// 100616237  NM_001202521 /// NM_001202522 /// NM_001202523...
# 1                   5982  NM_001278791 /// NM_001278792 /// NM_001278793...
# 2                   3310                                          NM_002155
# 3                   7849  NM_003466 /// NM_013951 /// NM_013952 /// NM_0...
# 4                   2978                         NM_000409 /// XM_006715073
# ...                  ...                                                ...
# 22278                NaN                                                NaN
# 22279                NaN                                                NaN
# 22280                NaN                                                NaN
# 22281                NaN                                                NaN
# 22282                NaN                                                NaN
#
#                         Gene Ontology Biological Process  \
# 0      0001558 // regulation of cell growth // inferr...
# 1      0000278 // mitotic cell cycle // traceable aut...
# 2      0000902 // cell morphogenesis // inferred from...
# 3      0001655 // urogenital system development // in...
# 4      0007165 // signal transduction // non-traceabl...
# ...                                                  ...
# 22278                                                NaN
# 22279                                                NaN
# 22280                                                NaN
# 22281                                                NaN
# 22282                                                NaN
#
#                         Gene Ontology Cellular Component  \
# 0      0005576 // extracellular region // inferred fr...
# 1      0005634 // nucleus // inferred from electronic...
# 2      0005737 // cytoplasm // inferred from direct a...
# 3      0005634 // nucleus // inferred from direct ass...
# 4      0001750 // photoreceptor outer segment // infe...
# ...                                                  ...
# 22278                                                NaN
# 22279                                                NaN
# 22280                                                NaN
# 22281                                                NaN
# 22282                                                NaN
#
#                         Gene Ontology Molecular Function
# 0      0000166 // nucleotide binding // inferred from...
# 1      0000166 // nucleotide binding // inferred from...
# 2      0000166 // nucleotide binding // inferred from...
# 3      0000979 // RNA polymerase II core promoter seq...
# 4      0005509 // calcium ion binding // inferred fro...
# ...                                                  ...
# 22278                                                NaN
# 22279                                                NaN
# 22280                                                NaN
# 22281                                                NaN
# 22282                                                NaN
#
# [22283 rows x 16 columns]

# %%
gsms = {}
genes = {}
gpls = {}
for gsm_name, gsm in gse.gsms.items():
#     for key, value in gsm.metadata.items():
#         print(" - %s : %s" % (key, ", ".join(value)))
    gsms[gsm_name] = gsm.metadata['characteristics_ch1']
    genes[gsm_name] = gsm.table

for gpl_name, gpl in gse.gpls.items():
#     for key, value in gpl.metadata.items():
#         print(" - %s : %s" % (key, ", ".join(value)))
    gpls[gpl_name] = gpl.table

# %%
genes
# Out:
# {'GSM177885':                 ID_REF      VALUE
#  0            1007_s_at  10.780787
#  1              1053_at   8.674201
#  2               117_at   7.738589
#  3               121_at   9.285511
#  4            1255_g_at   6.610484
#  ...                ...        ...
#  22278   AFFX-ThrX-5_at   5.680176
#  22279   AFFX-ThrX-M_at   1.753631
#  22280  AFFX-TrpnX-3_at   2.223181
#  22281  AFFX-TrpnX-5_at   4.013873
#  22282  AFFX-TrpnX-M_at   1.603252
#
#  [22283 rows x 2 columns],
#  'GSM177886':                 ID_REF      VALUE
#  0            1007_s_at  11.335393
#  1              1053_at   9.354759
#  2               117_at   7.763657
#  3               121_at   9.025809
#  4            1255_g_at   4.809869
#  ...                ...        ...
#  22278   AFFX-ThrX-5_at   2.888221
#  22279   AFFX-ThrX-M_at   1.767325
#  22280  AFFX-TrpnX-3_at   2.013092
#  22281  AFFX-TrpnX-5_at   5.355048
#  22282  AFFX-TrpnX-M_at   2.455589
#
#  [22283 rows x 2 columns],
#  'GSM177887':                 ID_REF      VALUE
#  0            1007_s_at  11.028074
#  1              1053_at   9.053889
#  2               117_at   6.327600
#  3               121_at   9.234409
#  4            1255_g_at   4.621973
#  ...                ...        ...
#  22278   AFFX-ThrX-5_at   3.464008
#  22279   AFFX-ThrX-M_at   4.875803
#  22280  AFFX-TrpnX-3_at   0.581058
#  22281  AFFX-TrpnX-5_at   4.054644
#  22282  AFFX-TrpnX-M_at   2.021403
#
#  [22283 rows x 2 columns],
#  'GSM177888':                 ID_REF      VALUE
#  0            1007_s_at  11.847736
#  1              1053_at   9.139895
#  2               117_at   7.032598
#  3               121_at   9.656416
#  4            1255_g_at   5.589404
#  ...                ...        ...
#  22278   AFFX-ThrX-5_at   5.564328
#  22279   AFFX-ThrX-M_at   3.361199
#  22280  AFFX-TrpnX-3_at   2.251075
#  22281  AFFX-TrpnX-5_at   4.760490
#  22282  AFFX-TrpnX-M_at   2.365204
#
#  [22283 rows x 2 columns],
#  'GSM177889':                 ID_REF      VALUE
#  0            1007_s_at  12.359239
#  1              1053_at   9.196708
#  2               117_at   7.873428
#  3               121_at   9.174188
#  4            1255_g_at   5.325173
#  ...                ...        ...
#  22278   AFFX-ThrX-5_at   5.957565
#  22279   AFFX-ThrX-M_at   2.400875
#  22280  AFFX-TrpnX-3_at   4.915962
#  22281  AFFX-TrpnX-5_at   6.120431
#  22282  AFFX-TrpnX-M_at   2.774229
#
#  [22283 rows x 2 columns],
#  'GSM177890':                 ID_REF      VALUE
#  0            1007_s_at  11.086998
#  1              1053_at   8.808035
#  2               117_at   6.140035
#  3               121_at   9.283764
#  4            1255_g_at   2.995857
#  ...                ...        ...
#  22278   AFFX-ThrX-5_at   1.740601
#  22279   AFFX-ThrX-M_at   5.284490
#  22280  AFFX-TrpnX-3_at   2.600288
#  22281  AFFX-TrpnX-5_at   4.468676
#  22282  AFFX-TrpnX-M_at   2.270242
#
#  [22283 rows x 2 columns],
#  'GSM177891':                 ID_REF      VALUE
#  0            1007_s_at  11.681446
#  1              1053_at   9.395361
#  2               117_at   7.401411
#  3               121_at   8.936069
#  4            1255_g_at   5.489110
#  ...                ...        ...
#  22278   AFFX-ThrX-5_at   2.093126
#  22279   AFFX-ThrX-M_at   4.893867
#  22280  AFFX-TrpnX-3_at   1.879390
#  22281  AFFX-TrpnX-5_at   3.794052
#  22282  AFFX-TrpnX-M_at   1.925874
#
#  [22283 rows x 2 columns],
#  'GSM177892':                 ID_REF      VALUE
#  0            1007_s_at  11.232548
#  1              1053_at   8.793770
#  2               117_at   7.338878
#  3               121_at   9.363308
#  4            1255_g_at   5.604046
#  ...                ...        ...
#  22278   AFFX-ThrX-5_at   3.763917
#  22279   AFFX-ThrX-M_at   4.095883
#  22280  AFFX-TrpnX-3_at   1.469121
#  22281  AFFX-TrpnX-5_at   4.822143
#  22282  AFFX-TrpnX-M_at   2.291870
#
#  [22283 rows x 2 columns],
#  'GSM177893':                 ID_REF      VALUE
#  0            1007_s_at  11.588695
#  1              1053_at   9.073383
#  2               117_at   6.597228
#  3               121_at   9.949485
#  4            1255_g_at   2.084769
#  ...                ...        ...
#  22278   AFFX-ThrX-5_at   4.399650
#  22279   AFFX-ThrX-M_at   5.130756
#  22280  AFFX-TrpnX-3_at   2.129731
#  22281  AFFX-TrpnX-5_at   3.711549
#  22282  AFFX-TrpnX-M_at   2.236214
#
#  [22283 rows x 2 columns],
#  'GSM177894':                 ID_REF      VALUE
#  0            1007_s_at  11.369830
#  1              1053_at   9.098997
#  2               117_at   4.728055
#  3               121_at   9.227627
#  4            1255_g_at   5.679486
#  ...                ...        ...
#  22278   AFFX-ThrX-5_at   3.744013
#  22279   AFFX-ThrX-M_at   3.828155
#  22280  AFFX-TrpnX-3_at   4.025017
#  22281  AFFX-TrpnX-5_at   3.809851
#  22282  AFFX-TrpnX-M_at   1.542741
#
#  [22283 rows x 2 columns],
#  'GSM177895':                 ID_REF      VALUE
#  0            1007_s_at  11.380786
#  1              1053_at   9.690694
#  2               117_at   6.563996
#  3               121_at   9.393946
#  4            1255_g_at   4.115647
#  ...                ...        ...
#  22278   AFFX-ThrX-5_at   3.249227
#  22279   AFFX-ThrX-M_at   2.195501
#  22280  AFFX-TrpnX-3_at   5.549835
#  22281  AFFX-TrpnX-5_at   6.058028
#  22282  AFFX-TrpnX-M_at   2.306382
#
#  [22283 rows x 2 columns],
#  'GSM177896':                 ID_REF      VALUE
#  0            1007_s_at  11.861173
#  1              1053_at   8.405692
#  2               117_at   5.981970
#  3               121_at   8.906455
#  4            1255_g_at   4.158243
#  ...                ...        ...
#  22278   AFFX-ThrX-5_at   3.818854
#  22279   AFFX-ThrX-M_at   3.468733
#  22280  AFFX-TrpnX-3_at   3.683680
#  22281  AFFX-TrpnX-5_at   2.717503
#  22282  AFFX-TrpnX-M_at   2.472065
#
#  [22283 rows x 2 columns],
#  'GSM177897':                 ID_REF      VALUE
#  0            1007_s_at  11.778795
#  1              1053_at   9.091645
#  2               117_at   6.449843
#  3               121_at   9.267778
#  4            1255_g_at   1.780311
#  ...                ...        ...
#  22278   AFFX-ThrX-5_at   4.239374
#  22279   AFFX-ThrX-M_at   2.606750
#  22280  AFFX-TrpnX-3_at   1.668582
#  22281  AFFX-TrpnX-5_at   3.526877
#  22282  AFFX-TrpnX-M_at   2.913033
#
#  [22283 rows x 2 columns],
#  'GSM177898':                 ID_REF      VALUE
#  0            1007_s_at  11.432256
#  1              1053_at   9.119084
#  2               117_at   6.351076
#  3               121_at   9.232208
#  4            1255_g_at   2.831200
#  ...                ...        ...
#  22278   AFFX-ThrX-5_at   3.050572
#  22279   AFFX-ThrX-M_at   3.462608
#  22280  AFFX-TrpnX-3_at   2.066692
#  22281  AFFX-TrpnX-5_at   5.397449
#  22282  AFFX-TrpnX-M_at   3.161664
#
#  [22283 rows x 2 columns],
#  'GSM177899':                 ID_REF      VALUE
#  0            1007_s_at  10.567699
#  1              1053_at   8.758636
#  2               117_at   7.008761
#  3               121_at   8.790084
#  4            1255_g_at   3.442355
#  ...                ...        ...
#  22278   AFFX-ThrX-5_at   3.093932
#  22279   AFFX-ThrX-M_at   2.774739
#  22280  AFFX-TrpnX-3_at   1.522285
#  22281  AFFX-TrpnX-5_at   4.727984
#  22282  AFFX-TrpnX-M_at   1.092883
#
#  [22283 rows x 2 columns],
#  'GSM177900':                 ID_REF      VALUE
#  0            1007_s_at  11.882812
#  1              1053_at   8.967280
#  2               117_at   6.656165
#  3               121_at   9.001399
#  4            1255_g_at   2.827426
#  ...                ...        ...
#  22278   AFFX-ThrX-5_at   3.925251
#  22279   AFFX-ThrX-M_at   2.003938
#  22280  AFFX-TrpnX-3_at   3.425787
#  22281  AFFX-TrpnX-5_at   2.698398
#  22282  AFFX-TrpnX-M_at   2.119970
#
#  [22283 rows x 2 columns],
#  'GSM177901':                 ID_REF      VALUE
#  0            1007_s_at  11.133012
#  1              1053_at   9.169519
#  2               117_at   6.806075
#  3               121_at   8.839512
#  4            1255_g_at   6.149450
#  ...                ...        ...
#  22278   AFFX-ThrX-5_at   3.789906
#  22279   AFFX-ThrX-M_at   2.087306
#  22280  AFFX-TrpnX-3_at   4.534320
#  22281  AFFX-TrpnX-5_at   3.030108
#  22282  AFFX-TrpnX-M_at   2.815744
#
#  [22283 rows x 2 columns],
#  'GSM177902':                 ID_REF      VALUE
#  0            1007_s_at  11.793967
#  1              1053_at   9.313454
#  2               117_at   6.213217
#  3               121_at   9.092036
#  4            1255_g_at   5.565654
#  ...                ...        ...
#  22278   AFFX-ThrX-5_at   3.776964
#  22279   AFFX-ThrX-M_at   2.471640
#  22280  AFFX-TrpnX-3_at   1.630375
#  22281  AFFX-TrpnX-5_at   4.968608
#  22282  AFFX-TrpnX-M_at   4.684593
#
#  [22283 rows x 2 columns],
#  'GSM177903':                 ID_REF     VALUE
#  0            1007_s_at  9.981324
#  1              1053_at  9.119762
#  2               117_at  6.696886
#  3               121_at  9.341235
#  4            1255_g_at  6.024515
#  ...                ...       ...
#  22278   AFFX-ThrX-5_at  4.491024
#  22279   AFFX-ThrX-M_at  5.468670
#  22280  AFFX-TrpnX-3_at  2.010029
#  22281  AFFX-TrpnX-5_at  5.374553
#  22282  AFFX-TrpnX-M_at  2.544848
#
#  [22283 rows x 2 columns],
#  'GSM177904':                 ID_REF      VALUE
#  0            1007_s_at  11.226784
#  1              1053_at   8.925031
#  2               117_at   6.075047
#  3               121_at   9.382504
#  4            1255_g_at   6.186761
#  ...                ...        ...
#  22278   AFFX-ThrX-5_at   5.724581
#  22279   AFFX-ThrX-M_at   2.648785
#  22280  AFFX-TrpnX-3_at   2.178374
#  22281  AFFX-TrpnX-5_at   5.145740
#  22282  AFFX-TrpnX-M_at   2.592158
#
#  [22283 rows x 2 columns],
#  'GSM177905':                 ID_REF      VALUE
#  0            1007_s_at  11.820420
#  1              1053_at   7.807689
#  2               117_at   5.935446
#  3               121_at   9.217080
#  4            1255_g_at   4.359779
#  ...                ...        ...
#  22278   AFFX-ThrX-5_at   2.627399
#  22279   AFFX-ThrX-M_at   5.089507
#  22280  AFFX-TrpnX-3_at   4.927622
#  22281  AFFX-TrpnX-5_at   2.964354
#  22282  AFFX-TrpnX-M_at   1.604485
#
#  [22283 rows x 2 columns],
#  'GSM177906':                 ID_REF      VALUE
#  0            1007_s_at  12.865772
#  1              1053_at   8.133041
#  2               117_at   7.191480
#  3               121_at   9.092309
#  4            1255_g_at   5.984168
#  ...                ...        ...
#  22278   AFFX-ThrX-5_at   5.770937
#  22279   AFFX-ThrX-M_at   4.762858
#  22280  AFFX-TrpnX-3_at   2.017651
#  22281  AFFX-TrpnX-5_at   5.216833
#  22282  AFFX-TrpnX-M_at   3.590986
#
#  [22283 rows x 2 columns],
#  'GSM177907':                 ID_REF      VALUE
#  0            1007_s_at  10.714060
#  1              1053_at   8.632991
#  2               117_at   7.253181
#  3               121_at   8.695573
#  4            1255_g_at   5.629914
#  ...                ...        ...
#  22278   AFFX-ThrX-5_at   2.993671
#  22279   AFFX-ThrX-M_at   2.378874
#  22280  AFFX-TrpnX-3_at   2.323849
#  22281  AFFX-TrpnX-5_at   4.902292
#  22282  AFFX-TrpnX-M_at   2.145998
#
#  [22283 rows x 2 columns],
#  'GSM177908':                 ID_REF      VALUE
#  0            1007_s_at  10.650251
#  1              1053_at   9.091251
#  2               117_at   6.795952
#  3               121_at   9.417101
#  4            1255_g_at   3.611647
#  ...                ...        ...
#  22278   AFFX-ThrX-5_at   4.914914
#  22279   AFFX-ThrX-M_at   3.634217
#  22280  AFFX-TrpnX-3_at   2.824442
#  22281  AFFX-TrpnX-5_at   3.275284
#  22282  AFFX-TrpnX-M_at   2.474540
#
#  [22283 rows x 2 columns],
#  'GSM177909':                 ID_REF      VALUE
#  0            1007_s_at  10.559347
#  1              1053_at   9.222955
#  2               117_at   6.217954
#  3               121_at   9.534851
#  4            1255_g_at   4.636145
#  ...                ...        ...
#  22278   AFFX-ThrX-5_at   3.588983
#  22279   AFFX-ThrX-M_at   2.408097
#  22280  AFFX-TrpnX-3_at   4.992709
#  22281  AFFX-TrpnX-5_at   5.879440
#  22282  AFFX-TrpnX-M_at   1.626629
#
#  [22283 rows x 2 columns],
#  'GSM177910':                 ID_REF      VALUE
#  0            1007_s_at  11.444653
#  1              1053_at   8.296057
#  2               117_at   7.209402
#  3               121_at  10.005488
#  4            1255_g_at   6.860824
#  ...                ...        ...
#  22278   AFFX-ThrX-5_at   5.890688
#  22279   AFFX-ThrX-M_at   2.166280
#  22280  AFFX-TrpnX-3_at   2.927970
#  22281  AFFX-TrpnX-5_at   3.589158
#  22282  AFFX-TrpnX-M_at   2.395242
#
#  [22283 rows x 2 columns],
#  'GSM177911':                 ID_REF      VALUE
#  0            1007_s_at  11.187064
#  1              1053_at   8.131038
#  2               117_at   6.562450
#  3               121_at   9.282701
#  4            1255_g_at   6.100067
#  ...                ...        ...
#  22278   AFFX-ThrX-5_at   2.907547
#  22279   AFFX-ThrX-M_at   3.403542
#  22280  AFFX-TrpnX-3_at   3.919984
#  22281  AFFX-TrpnX-5_at   2.567047
#  22282  AFFX-TrpnX-M_at   2.473976
#
#  [22283 rows x 2 columns],
#  'GSM177912':                 ID_REF      VALUE
#  0            1007_s_at  11.746824
#  1              1053_at   7.803727
#  2               117_at   4.802773
#  3               121_at   9.148742
#  4            1255_g_at   6.321756
#  ...                ...        ...
#  22278   AFFX-ThrX-5_at   3.027642
#  22279   AFFX-ThrX-M_at   5.906083
#  22280  AFFX-TrpnX-3_at   5.807191
#  22281  AFFX-TrpnX-5_at   6.376417
#  22282  AFFX-TrpnX-M_at   2.216346
#
#  [22283 rows x 2 columns],
#  'GSM177913':                 ID_REF      VALUE
#  0            1007_s_at  11.568741
#  1              1053_at   9.303138
#  2               117_at   6.876397
#  3               121_at   9.362312
#  4            1255_g_at   4.750811
#  ...                ...        ...
#  22278   AFFX-ThrX-5_at   4.438060
#  22279   AFFX-ThrX-M_at   3.157433
#  22280  AFFX-TrpnX-3_at   4.687558
#  22281  AFFX-TrpnX-5_at   2.458279
#  22282  AFFX-TrpnX-M_at   1.945593
#
#  [22283 rows x 2 columns],
#  'GSM177914':                 ID_REF      VALUE
#  0            1007_s_at  11.157951
#  1              1053_at   8.110391
#  2               117_at   6.979338
#  3               121_at   9.025666
#  4            1255_g_at   6.143258
#  ...                ...        ...
#  22278   AFFX-ThrX-5_at   3.409143
#  22279   AFFX-ThrX-M_at   3.530103
#  22280  AFFX-TrpnX-3_at   3.307354
#  22281  AFFX-TrpnX-5_at   5.499766
#  22282  AFFX-TrpnX-M_at   3.736658
#
#  [22283 rows x 2 columns],
#  'GSM177915':                 ID_REF      VALUE
#  0            1007_s_at  11.007239
#  1              1053_at   8.551045
#  2               117_at   7.212747
#  3               121_at   9.314258
#  4            1255_g_at   4.847646
#  ...                ...        ...
#  22278   AFFX-ThrX-5_at   2.566490
#  22279   AFFX-ThrX-M_at   4.698280
#  22280  AFFX-TrpnX-3_at   5.246112
#  22281  AFFX-TrpnX-5_at   3.599129
#  22282  AFFX-TrpnX-M_at   2.767721
#
#  [22283 rows x 2 columns],
#  'GSM177916':                 ID_REF      VALUE
#  0            1007_s_at  10.413946
#  1              1053_at   9.396683
#  2               117_at   6.448100
#  3               121_at   9.557346
#  4            1255_g_at   4.890520
#  ...                ...        ...
#  22278   AFFX-ThrX-5_at   2.522797
#  22279   AFFX-ThrX-M_at   3.545242
#  22280  AFFX-TrpnX-3_at   2.868471
#  22281  AFFX-TrpnX-5_at   4.030695
#  22282  AFFX-TrpnX-M_at   2.423719
#
#  [22283 rows x 2 columns],
#  'GSM177917':                 ID_REF      VALUE
#  0            1007_s_at  11.637455
#  1              1053_at   8.851429
#  2               117_at   4.991313
#  3               121_at   9.417069
#  4            1255_g_at   5.639863
#  ...                ...        ...
#  22278   AFFX-ThrX-5_at   3.218647
#  22279   AFFX-ThrX-M_at   5.703618
#  22280  AFFX-TrpnX-3_at   2.638117
#  22281  AFFX-TrpnX-5_at   4.479257
#  22282  AFFX-TrpnX-M_at   2.146295
#
#  [22283 rows x 2 columns],
#  'GSM177918':                 ID_REF      VALUE
#  0            1007_s_at  11.053213
#  1              1053_at   8.521082
#  2               117_at   7.080011
#  3               121_at   8.763788
#  4            1255_g_at   5.713005
#  ...                ...        ...
#  22278   AFFX-ThrX-5_at   5.205902
#  22279   AFFX-ThrX-M_at   3.134910
#  22280  AFFX-TrpnX-3_at   1.949247
#  22281  AFFX-TrpnX-5_at   4.747542
#  22282  AFFX-TrpnX-M_at   2.434661
#
#  [22283 rows x 2 columns],
#  'GSM177919':                 ID_REF      VALUE
#  0            1007_s_at  11.479657
#  1              1053_at   7.658026
#  2               117_at   7.046585
#  3               121_at   9.038510
#  4            1255_g_at   3.817848
#  ...                ...        ...
#  22278   AFFX-ThrX-5_at   3.727822
#  22279   AFFX-ThrX-M_at   5.452721
#  22280  AFFX-TrpnX-3_at   1.297548
#  22281  AFFX-TrpnX-5_at   3.589881
#  22282  AFFX-TrpnX-M_at   2.057157
#
#  [22283 rows x 2 columns],
#  'GSM177920':                 ID_REF      VALUE
#  0            1007_s_at  11.424564
#  1              1053_at   8.480248
#  2               117_at   6.801191
#  3               121_at   8.645601
#  4            1255_g_at   5.086902
#  ...                ...        ...
#  22278   AFFX-ThrX-5_at   3.324608
#  22279   AFFX-ThrX-M_at   2.108851
#  22280  AFFX-TrpnX-3_at   5.042908
#  22281  AFFX-TrpnX-5_at   3.407239
#  22282  AFFX-TrpnX-M_at   2.247065
#
#  [22283 rows x 2 columns],
#  'GSM177921':                 ID_REF      VALUE
#  0            1007_s_at  11.930869
#  1              1053_at   8.278712
#  2               117_at   5.966474
#  3               121_at   9.023134
#  4            1255_g_at   3.586880
#  ...                ...        ...
#  22278   AFFX-ThrX-5_at   2.311595
#  22279   AFFX-ThrX-M_at   4.513916
#  22280  AFFX-TrpnX-3_at   1.356990
#  22281  AFFX-TrpnX-5_at   4.169797
#  22282  AFFX-TrpnX-M_at   2.802478
#
#  [22283 rows x 2 columns],
#  'GSM177922':                 ID_REF      VALUE
#  0            1007_s_at  11.622559
#  1              1053_at   8.525585
#  2               117_at   6.867930
#  3               121_at   8.999614
#  4            1255_g_at   6.299449
#  ...                ...        ...
#  22278   AFFX-ThrX-5_at   5.756820
#  22279   AFFX-ThrX-M_at   6.304429
#  22280  AFFX-TrpnX-3_at   2.361450
#  22281  AFFX-TrpnX-5_at   2.961837
#  22282  AFFX-TrpnX-M_at   1.701993
#
#  [22283 rows x 2 columns],
#  'GSM177923':                 ID_REF      VALUE
#  0            1007_s_at  11.903317
#  1              1053_at   9.107779
#  2               117_at   7.236456
#  3               121_at   9.528990
#  4            1255_g_at   5.880816
#  ...                ...        ...
#  22278   AFFX-ThrX-5_at   6.517542
#  22279   AFFX-ThrX-M_at   3.275442
#  22280  AFFX-TrpnX-3_at   1.861570
#  22281  AFFX-TrpnX-5_at   5.194256
#  22282  AFFX-TrpnX-M_at   2.139527
#
#  [22283 rows x 2 columns],
#  'GSM177924':                 ID_REF      VALUE
#  0            1007_s_at  11.412445
#  1              1053_at   8.555952
#  2               117_at   6.820620
#  3               121_at   8.973308
#  4            1255_g_at   6.121707
#  ...                ...        ...
#  22278   AFFX-ThrX-5_at   3.404225
#  22279   AFFX-ThrX-M_at   3.300903
#  22280  AFFX-TrpnX-3_at   2.207489
#  22281  AFFX-TrpnX-5_at   3.551524
#  22282  AFFX-TrpnX-M_at   2.260118
#
#  [22283 rows x 2 columns],
#  'GSM177925':                 ID_REF      VALUE
#  0            1007_s_at  10.098108
#  1              1053_at   8.569407
#  2               117_at   7.002737
#  3               121_at   9.160008
#  4            1255_g_at   4.196589
#  ...                ...        ...
#  22278   AFFX-ThrX-5_at   5.677618
#  22279   AFFX-ThrX-M_at   2.206449
#  22280  AFFX-TrpnX-3_at   3.853324
#  22281  AFFX-TrpnX-5_at   6.025330
#  22282  AFFX-TrpnX-M_at   5.188082
#
#  [22283 rows x 2 columns],
#  'GSM177926':                 ID_REF      VALUE
#  0            1007_s_at  11.864499
#  1              1053_at   8.239933
#  2               117_at   8.044176
#  3               121_at   9.507124
#  4            1255_g_at   4.064099
#  ...                ...        ...
#  22278   AFFX-ThrX-5_at   7.042162
#  22279   AFFX-ThrX-M_at   5.010361
#  22280  AFFX-TrpnX-3_at   3.067963
#  22281  AFFX-TrpnX-5_at   6.553828
#  22282  AFFX-TrpnX-M_at   3.471888
#
#  [22283 rows x 2 columns],
#  'GSM177927':                 ID_REF      VALUE
#  0            1007_s_at  11.337224
#  1              1053_at   8.936711
#  2               117_at   8.136148
#  3               121_at   9.007508
#  4            1255_g_at   6.299405
#  ...                ...        ...
#  22278   AFFX-ThrX-5_at   4.023610
#  22279   AFFX-ThrX-M_at   3.935651
#  22280  AFFX-TrpnX-3_at   2.284058
#  22281  AFFX-TrpnX-5_at   3.899786
#  22282  AFFX-TrpnX-M_at   3.804570
#
#  [22283 rows x 2 columns],
#  'GSM177928':                 ID_REF      VALUE
#  0            1007_s_at  11.425808
#  1              1053_at   9.606283
#  2               117_at   7.030485
#  3               121_at   9.376982
#  4            1255_g_at   6.100300
#  ...                ...        ...
#  22278   AFFX-ThrX-5_at   3.167232
#  22279   AFFX-ThrX-M_at   1.024564
#  22280  AFFX-TrpnX-3_at   0.716203
#  22281  AFFX-TrpnX-5_at   1.788110
#  22282  AFFX-TrpnX-M_at   1.895791
#
#  [22283 rows x 2 columns],
#  'GSM177929':                 ID_REF      VALUE
#  0            1007_s_at  11.907724
#  1              1053_at   9.908545
#  2               117_at   6.838520
#  3               121_at   8.827427
#  4            1255_g_at   4.169865
#  ...                ...        ...
#  22278   AFFX-ThrX-5_at   1.753358
#  22279   AFFX-ThrX-M_at   5.344715
#  22280  AFFX-TrpnX-3_at   2.547434
#  22281  AFFX-TrpnX-5_at   3.215209
#  22282  AFFX-TrpnX-M_at   1.372067
#
#  [22283 rows x 2 columns],
#  'GSM177930':                 ID_REF      VALUE
#  0            1007_s_at  11.366738
#  1              1053_at   8.849618
#  2               117_at   7.354270
#  3               121_at   9.583852
#  4            1255_g_at   3.738628
#  ...                ...        ...
#  22278   AFFX-ThrX-5_at   3.959578
#  22279   AFFX-ThrX-M_at   4.304935
#  22280  AFFX-TrpnX-3_at   2.080821
#  22281  AFFX-TrpnX-5_at   2.743693
#  22282  AFFX-TrpnX-M_at   2.658697
#
#  [22283 rows x 2 columns],
#  'GSM177931':                 ID_REF      VALUE
#  0            1007_s_at  10.892405
#  1              1053_at   7.847566
#  2               117_at   7.111087
#  3               121_at   8.796280
#  4            1255_g_at   3.927390
#  ...                ...        ...
#  22278   AFFX-ThrX-5_at   2.725602
#  22279   AFFX-ThrX-M_at   3.319546
#  22280  AFFX-TrpnX-3_at   2.710428
#  22281  AFFX-TrpnX-5_at   3.326303
#  22282  AFFX-TrpnX-M_at   2.988855
#
#  [22283 rows x 2 columns],
#  'GSM177932':                 ID_REF      VALUE
#  0            1007_s_at  11.563466
#  1              1053_at   8.697093
#  2               117_at   7.480722
#  3               121_at   9.358845
#  4            1255_g_at   5.183691
#  ...                ...        ...
#  22278   AFFX-ThrX-5_at   3.468185
#  22279   AFFX-ThrX-M_at   4.869632
#  22280  AFFX-TrpnX-3_at   4.993247
#  22281  AFFX-TrpnX-5_at   1.936227
#  22282  AFFX-TrpnX-M_at   1.925724
#
#  [22283 rows x 2 columns],
#  'GSM177933':                 ID_REF      VALUE
#  0            1007_s_at  11.434352
#  1              1053_at   9.191749
#  2               117_at   7.140296
#  3               121_at   8.614260
#  4            1255_g_at   5.570317
#  ...                ...        ...
#  22278   AFFX-ThrX-5_at   3.298056
#  22279   AFFX-ThrX-M_at   2.835777
#  22280  AFFX-TrpnX-3_at   4.603920
#  22281  AFFX-TrpnX-5_at   5.063926
#  22282  AFFX-TrpnX-M_at   2.081849
#
#  [22283 rows x 2 columns],
#  'GSM177934':                 ID_REF      VALUE
#  0            1007_s_at  11.734315
#  1              1053_at   9.551406
#  2               117_at   6.790068
#  3               121_at   9.585630
#  4            1255_g_at   2.811026
#  ...                ...        ...
#  22278   AFFX-ThrX-5_at   5.005647
#  22279   AFFX-ThrX-M_at   5.526304
#  22280  AFFX-TrpnX-3_at   4.856860
#  22281  AFFX-TrpnX-5_at   4.303548
#  22282  AFFX-TrpnX-M_at   2.078403
#
#  [22283 rows x 2 columns],
#  'GSM177935':                 ID_REF      VALUE
#  0            1007_s_at  11.007242
#  1              1053_at   9.227358
#  2               117_at   7.001006
#  3               121_at   9.425522
#  4            1255_g_at   5.736816
#  ...                ...        ...
#  22278   AFFX-ThrX-5_at   2.064501
#  22279   AFFX-ThrX-M_at   2.083847
#  22280  AFFX-TrpnX-3_at   4.793897
#  22281  AFFX-TrpnX-5_at   3.380032
#  22282  AFFX-TrpnX-M_at   1.294358
#
#  [22283 rows x 2 columns],
#  'GSM177936':                 ID_REF      VALUE
#  0            1007_s_at  10.908339
#  1              1053_at   8.776457
#  2               117_at   7.086357
#  3               121_at   9.258327
#  4            1255_g_at   5.281330
#  ...                ...        ...
#  22278   AFFX-ThrX-5_at   2.551792
#  22279   AFFX-ThrX-M_at   2.151648
#  22280  AFFX-TrpnX-3_at   4.543392
#  22281  AFFX-TrpnX-5_at   2.709943
#  22282  AFFX-TrpnX-M_at   1.215531
#
#  [22283 rows x 2 columns],
#  'GSM177937':                 ID_REF      VALUE
#  0            1007_s_at  11.211656
#  1              1053_at   8.975770
#  2               117_at   8.073386
#  3               121_at   9.230322
#  4            1255_g_at   6.319834
#  ...                ...        ...
#  22278   AFFX-ThrX-5_at   3.158312
#  22279   AFFX-ThrX-M_at   3.639750
#  22280  AFFX-TrpnX-3_at   1.710888
#  22281  AFFX-TrpnX-5_at   3.424962
#  22282  AFFX-TrpnX-M_at   3.776587
#
#  [22283 rows x 2 columns],
#  'GSM177938':                 ID_REF      VALUE
#  0            1007_s_at  11.428266
#  1              1053_at   8.057004
#  2               117_at   7.542193
#  3               121_at   8.874393
#  4            1255_g_at   4.173192
#  ...                ...        ...
#  22278   AFFX-ThrX-5_at   2.629774
#  22279   AFFX-ThrX-M_at   3.567465
#  22280  AFFX-TrpnX-3_at   2.520235
#  22281  AFFX-TrpnX-5_at   3.281809
#  22282  AFFX-TrpnX-M_at   1.883143
#
#  [22283 rows x 2 columns],
#  'GSM177939':                 ID_REF      VALUE
#  0            1007_s_at  10.993199
#  1              1053_at   9.429854
#  2               117_at   7.420909
#  3               121_at   8.689326
#  4            1255_g_at   3.579122
#  ...                ...        ...
#  22278   AFFX-ThrX-5_at   3.535298
#  22279   AFFX-ThrX-M_at   5.284044
#  22280  AFFX-TrpnX-3_at   1.675649
#  22281  AFFX-TrpnX-5_at   6.179950
#  22282  AFFX-TrpnX-M_at   3.467227
#
#  [22283 rows x 2 columns],
#  'GSM177940':                 ID_REF      VALUE
#  0            1007_s_at  11.685822
#  1              1053_at   8.022957
#  2               117_at   8.147801
#  3               121_at   9.793265
#  4            1255_g_at   6.356923
#  ...                ...        ...
#  22278   AFFX-ThrX-5_at   2.596847
#  22279   AFFX-ThrX-M_at   2.352495
#  22280  AFFX-TrpnX-3_at   4.614673
#  22281  AFFX-TrpnX-5_at   4.463050
#  22282  AFFX-TrpnX-M_at   1.453688
#
#  [22283 rows x 2 columns],
#  'GSM177941':                 ID_REF      VALUE
#  0            1007_s_at  11.766143
#  1              1053_at   9.186259
#  2               117_at   6.997115
#  3               121_at   9.296144
#  4            1255_g_at   3.725443
#  ...                ...        ...
#  22278   AFFX-ThrX-5_at   2.854452
#  22279   AFFX-ThrX-M_at   3.870772
#  22280  AFFX-TrpnX-3_at   5.304365
#  22281  AFFX-TrpnX-5_at   3.555923
#  22282  AFFX-TrpnX-M_at   1.720068
#
#  [22283 rows x 2 columns],
#  'GSM177942':                 ID_REF      VALUE
#  0            1007_s_at  11.077609
#  1              1053_at   8.851917
#  2               117_at   6.425539
#  3               121_at   9.818579
#  4            1255_g_at   6.266990
#  ...                ...        ...
#  22278   AFFX-ThrX-5_at   3.692330
#  22279   AFFX-ThrX-M_at   1.998991
#  22280  AFFX-TrpnX-3_at   5.160173
#  22281  AFFX-TrpnX-5_at   1.948768
#  22282  AFFX-TrpnX-M_at   2.392535
#
#  [22283 rows x 2 columns],
#  'GSM177943':                 ID_REF      VALUE
#  0            1007_s_at  10.528023
#  1              1053_at   8.946694
#  2               117_at   8.815665
#  3               121_at   8.920367
#  4            1255_g_at   4.274809
#  ...                ...        ...
#  22278   AFFX-ThrX-5_at   3.209107
#  22279   AFFX-ThrX-M_at   3.545946
#  22280  AFFX-TrpnX-3_at   4.400406
#  22281  AFFX-TrpnX-5_at   5.911159
#  22282  AFFX-TrpnX-M_at   2.279087
#
#  [22283 rows x 2 columns],
#  'GSM177944':                 ID_REF     VALUE
#  0            1007_s_at  8.522833
#  1              1053_at  9.869941
#  2               117_at  7.656497
#  3               121_at  9.326288
#  4            1255_g_at  6.278423
#  ...                ...       ...
#  22278   AFFX-ThrX-5_at  2.749189
#  22279   AFFX-ThrX-M_at  1.844791
#  22280  AFFX-TrpnX-3_at  1.690170
#  22281  AFFX-TrpnX-5_at  4.014483
#  22282  AFFX-TrpnX-M_at  2.460734
#
#  [22283 rows x 2 columns],
#  'GSM177945':                 ID_REF      VALUE
#  0            1007_s_at  10.939316
#  1              1053_at   8.949855
#  2               117_at   9.973299
#  3               121_at   9.414874
#  4            1255_g_at   5.533361
#  ...                ...        ...
#  22278   AFFX-ThrX-5_at   3.555960
#  22279   AFFX-ThrX-M_at   2.113438
#  22280  AFFX-TrpnX-3_at   1.999745
#  22281  AFFX-TrpnX-5_at   5.921881
#  22282  AFFX-TrpnX-M_at   1.638457
#
#  [22283 rows x 2 columns],
#  'GSM177946':                 ID_REF      VALUE
#  0            1007_s_at  11.727150
#  1              1053_at   9.208373
#  2               117_at   7.027227
#  3               121_at   9.050230
#  4            1255_g_at   4.701947
#  ...                ...        ...
#  22278   AFFX-ThrX-5_at   5.262533
#  22279   AFFX-ThrX-M_at   2.225646
#  22280  AFFX-TrpnX-3_at   0.894443
#  22281  AFFX-TrpnX-5_at   4.942644
#  22282  AFFX-TrpnX-M_at   2.438822
#
#  [22283 rows x 2 columns],
#  'GSM177947':                 ID_REF      VALUE
#  0            1007_s_at  10.922352
#  1              1053_at   8.020642
#  2               117_at   6.462433
#  3               121_at   9.301462
#  4            1255_g_at   5.747236
#  ...                ...        ...
#  22278   AFFX-ThrX-5_at   1.924614
#  22279   AFFX-ThrX-M_at   2.230550
#  22280  AFFX-TrpnX-3_at   2.426083
#  22281  AFFX-TrpnX-5_at   3.698795
#  22282  AFFX-TrpnX-M_at   1.866488
#
#  [22283 rows x 2 columns],
#  'GSM177948':                 ID_REF      VALUE
#  0            1007_s_at  10.412720
#  1              1053_at   9.169138
#  2               117_at   6.472012
#  3               121_at   9.079316
#  4            1255_g_at   5.979137
#  ...                ...        ...
#  22278   AFFX-ThrX-5_at   3.559351
#  22279   AFFX-ThrX-M_at   3.255968
#  22280  AFFX-TrpnX-3_at   3.060826
#  22281  AFFX-TrpnX-5_at   5.290244
#  22282  AFFX-TrpnX-M_at   2.652161
#
#  [22283 rows x 2 columns],
#  'GSM177949':                 ID_REF      VALUE
#  0            1007_s_at  12.769519
#  1              1053_at   8.749540
#  2               117_at   6.398899
#  3               121_at   9.652291
#  4            1255_g_at   3.351932
#  ...                ...        ...
#  22278   AFFX-ThrX-5_at   3.888157
#  22279   AFFX-ThrX-M_at   5.587431
#  22280  AFFX-TrpnX-3_at   3.345151
#  22281  AFFX-TrpnX-5_at   3.077901
#  22282  AFFX-TrpnX-M_at   2.876065
#
#  [22283 rows x 2 columns],
#  'GSM177950':                 ID_REF      VALUE
#  0            1007_s_at  11.076690
#  1              1053_at   9.045297
#  2               117_at   8.706545
#  3               121_at   9.336372
#  4            1255_g_at   6.638364
#  ...                ...        ...
#  22278   AFFX-ThrX-5_at   2.350994
#  22279   AFFX-ThrX-M_at   1.231417
#  22280  AFFX-TrpnX-3_at   1.868414
#  22281  AFFX-TrpnX-5_at   3.124480
#  22282  AFFX-TrpnX-M_at   2.815911
#
#  [22283 rows x 2 columns],
#  'GSM177951':                 ID_REF      VALUE
#  0            1007_s_at  11.011525
#  1              1053_at   9.863536
#  2               117_at   7.885188
#  3               121_at   9.104513
#  4            1255_g_at   6.175406
#  ...                ...        ...
#  22278   AFFX-ThrX-5_at   5.239910
#  22279   AFFX-ThrX-M_at   2.949415
#  22280  AFFX-TrpnX-3_at   3.846334
#  22281  AFFX-TrpnX-5_at   6.983007
#  22282  AFFX-TrpnX-M_at   2.338567
#
#  [22283 rows x 2 columns],
#  'GSM177952':                 ID_REF      VALUE
#  0            1007_s_at  10.568007
#  1              1053_at   9.159727
#  2               117_at   6.046194
#  3               121_at   9.418463
#  4            1255_g_at   3.777075
#  ...                ...        ...
#  22278   AFFX-ThrX-5_at   6.006161
#  22279   AFFX-ThrX-M_at   4.540818
#  22280  AFFX-TrpnX-3_at   2.904777
#  22281  AFFX-TrpnX-5_at   3.753754
#  22282  AFFX-TrpnX-M_at   2.561027
#
#  [22283 rows x 2 columns],
#  'GSM177953':                 ID_REF      VALUE
#  0            1007_s_at  11.770141
#  1              1053_at   9.184640
#  2               117_at   7.217418
#  3               121_at   9.719951
#  4            1255_g_at   4.980175
#  ...                ...        ...
#  22278   AFFX-ThrX-5_at   2.686569
#  22279   AFFX-ThrX-M_at   2.100422
#  22280  AFFX-TrpnX-3_at   2.264185
#  22281  AFFX-TrpnX-5_at   4.091105
#  22282  AFFX-TrpnX-M_at   2.040172
#
#  [22283 rows x 2 columns],
#  'GSM177954':                 ID_REF      VALUE
#  0            1007_s_at  11.083145
#  1              1053_at   9.690626
#  2               117_at   8.741352
#  3               121_at   8.894790
#  4            1255_g_at   6.102090
#  ...                ...        ...
#  22278   AFFX-ThrX-5_at   4.234575
#  22279   AFFX-ThrX-M_at   3.689448
#  22280  AFFX-TrpnX-3_at   2.034506
#  22281  AFFX-TrpnX-5_at   4.108680
#  22282  AFFX-TrpnX-M_at   2.440172
#
#  [22283 rows x 2 columns],
#  'GSM177955':                 ID_REF      VALUE
#  0            1007_s_at  12.318368
#  1              1053_at   8.839247
#  2               117_at   6.935770
#  3               121_at  10.014590
#  4            1255_g_at   2.535546
#  ...                ...        ...
#  22278   AFFX-ThrX-5_at   4.041886
#  22279   AFFX-ThrX-M_at   3.320333
#  22280  AFFX-TrpnX-3_at   3.040819
#  22281  AFFX-TrpnX-5_at   2.962212
#  22282  AFFX-TrpnX-M_at   1.910183
#
#  [22283 rows x 2 columns],
#  'GSM177956':                 ID_REF      VALUE
#  0            1007_s_at  10.796345
#  1              1053_at   8.606736
#  2               117_at   7.506931
#  3               121_at   9.707202
#  4            1255_g_at   4.785624
#  ...                ...        ...
#  22278   AFFX-ThrX-5_at   3.908505
#  22279   AFFX-ThrX-M_at   3.184057
#  22280  AFFX-TrpnX-3_at   5.165964
#  22281  AFFX-TrpnX-5_at   4.743801
#  22282  AFFX-TrpnX-M_at   2.790303
#
#  [22283 rows x 2 columns],
#  'GSM177957':                 ID_REF      VALUE
#  0            1007_s_at  10.820360
#  1              1053_at   9.065078
#  2               117_at   6.056724
#  3               121_at   9.335537
#  4            1255_g_at   4.758654
#  ...                ...        ...
#  22278   AFFX-ThrX-5_at   3.983072
#  22279   AFFX-ThrX-M_at   2.397406
#  22280  AFFX-TrpnX-3_at   2.998330
#  22281  AFFX-TrpnX-5_at   5.691438
#  22282  AFFX-TrpnX-M_at   2.869315
#
#  [22283 rows x 2 columns],
#  'GSM177958':                 ID_REF      VALUE
#  0            1007_s_at  11.584473
#  1              1053_at   8.596354
#  2               117_at   7.355524
#  3               121_at   9.491634
#  4            1255_g_at   5.187692
#  ...                ...        ...
#  22278   AFFX-ThrX-5_at   4.213224
#  22279   AFFX-ThrX-M_at   3.478539
#  22280  AFFX-TrpnX-3_at   2.609336
#  22281  AFFX-TrpnX-5_at   2.873414
#  22282  AFFX-TrpnX-M_at   2.497213
#
#  [22283 rows x 2 columns],
#  'GSM177959':                 ID_REF      VALUE
#  0            1007_s_at  10.957762
#  1              1053_at   8.856351
#  2               117_at   6.830146
#  3               121_at   9.183630
#  4            1255_g_at   3.928619
#  ...                ...        ...
#  22278   AFFX-ThrX-5_at   1.916222
#  22279   AFFX-ThrX-M_at   1.620214
#  22280  AFFX-TrpnX-3_at   2.902096
#  22281  AFFX-TrpnX-5_at   3.530295
#  22282  AFFX-TrpnX-M_at   3.192306
#
#  [22283 rows x 2 columns],
#  'GSM177960':                 ID_REF      VALUE
#  0            1007_s_at  11.120387
#  1              1053_at   9.219647
#  2               117_at   7.532484
#  3               121_at   9.363774
#  4            1255_g_at   6.504305
#  ...                ...        ...
#  22278   AFFX-ThrX-5_at   6.439911
#  22279   AFFX-ThrX-M_at   5.094975
#  22280  AFFX-TrpnX-3_at   4.855935
#  22281  AFFX-TrpnX-5_at   6.487040
#  22282  AFFX-TrpnX-M_at   2.381351
#
#  [22283 rows x 2 columns],
#  'GSM177961':                 ID_REF      VALUE
#  0            1007_s_at  11.923922
#  1              1053_at   8.721461
#  2               117_at   7.083958
#  3               121_at   8.914869
#  4            1255_g_at   4.617242
#  ...                ...        ...
#  22278   AFFX-ThrX-5_at   3.896140
#  22279   AFFX-ThrX-M_at   1.219666
#  22280  AFFX-TrpnX-3_at   2.090974
#  22281  AFFX-TrpnX-5_at   3.058294
#  22282  AFFX-TrpnX-M_at   3.153638
#
#  [22283 rows x 2 columns],
#  'GSM177962':                 ID_REF      VALUE
#  0            1007_s_at  12.063765
#  1              1053_at   9.110408
#  2               117_at   7.052651
#  3               121_at   9.734264
#  4            1255_g_at   4.217090
#  ...                ...        ...
#  22278   AFFX-ThrX-5_at   4.217590
#  22279   AFFX-ThrX-M_at   5.196029
#  22280  AFFX-TrpnX-3_at   5.603168
#  22281  AFFX-TrpnX-5_at   5.319413
#  22282  AFFX-TrpnX-M_at   2.438344
#
#  [22283 rows x 2 columns],
#  'GSM177963':                 ID_REF      VALUE
#  0            1007_s_at  10.274131
#  1              1053_at  10.063265
#  2               117_at   7.891040
#  3               121_at   8.873234
#  4            1255_g_at   6.263550
#  ...                ...        ...
#  22278   AFFX-ThrX-5_at   2.758845
#  22279   AFFX-ThrX-M_at   2.859908
#  22280  AFFX-TrpnX-3_at   2.152967
#  22281  AFFX-TrpnX-5_at   2.913277
#  22282  AFFX-TrpnX-M_at   1.253523
#
#  [22283 rows x 2 columns],
#  'GSM177964':                 ID_REF      VALUE
#  0            1007_s_at  11.240575
#  1              1053_at   8.501709
#  2               117_at   6.777821
#  3               121_at   9.847016
#  4            1255_g_at   3.790499
#  ...                ...        ...
#  22278   AFFX-ThrX-5_at   4.008873
#  22279   AFFX-ThrX-M_at   4.855167
#  22280  AFFX-TrpnX-3_at   3.062173
#  22281  AFFX-TrpnX-5_at   3.135872
#  22282  AFFX-TrpnX-M_at   3.122359
#
#  [22283 rows x 2 columns],
#  'GSM177965':                 ID_REF      VALUE
#  0            1007_s_at  11.390171
#  1              1053_at   8.092258
#  2               117_at   7.119871
#  3               121_at   9.113664
#  4            1255_g_at   6.327833
#  ...                ...        ...
#  22278   AFFX-ThrX-5_at   3.605339
#  22279   AFFX-ThrX-M_at   4.919213
#  22280  AFFX-TrpnX-3_at   1.812420
#  22281  AFFX-TrpnX-5_at   5.742734
#  22282  AFFX-TrpnX-M_at   2.811880
#
#  [22283 rows x 2 columns],
#  'GSM177966':                 ID_REF      VALUE
#  0            1007_s_at  10.348403
#  1              1053_at   9.315253
#  2               117_at   7.544797
#  3               121_at   8.729500
#  4            1255_g_at   5.949961
#  ...                ...        ...
#  22278   AFFX-ThrX-5_at   2.711454
#  22279   AFFX-ThrX-M_at   4.197043
#  22280  AFFX-TrpnX-3_at   0.924155
#  22281  AFFX-TrpnX-5_at   1.727203
#  22282  AFFX-TrpnX-M_at   1.757243
#
#  [22283 rows x 2 columns],
#  'GSM177967':                 ID_REF      VALUE
#  0            1007_s_at  11.682199
#  1              1053_at   8.279976
#  2               117_at   7.249127
#  3               121_at  10.072163
#  4            1255_g_at   6.107334
#  ...                ...        ...
#  22278   AFFX-ThrX-5_at   3.349245
#  22279   AFFX-ThrX-M_at   5.989684
#  22280  AFFX-TrpnX-3_at   5.001357
#  22281  AFFX-TrpnX-5_at   3.727285
#  22282  AFFX-TrpnX-M_at   2.071616
#
#  [22283 rows x 2 columns],
#  'GSM177968':                 ID_REF      VALUE
#  0            1007_s_at  11.213938
#  1              1053_at   9.287873
#  2               117_at   7.528829
#  3               121_at   9.109142
#  4            1255_g_at   5.765547
#  ...                ...        ...
#  22278   AFFX-ThrX-5_at   3.244201
#  22279   AFFX-ThrX-M_at   2.064294
#  22280  AFFX-TrpnX-3_at   1.192792
#  22281  AFFX-TrpnX-5_at   4.142828
#  22282  AFFX-TrpnX-M_at   2.688090
#
#  [22283 rows x 2 columns],
#  'GSM177969':                 ID_REF      VALUE
#  0            1007_s_at  10.838459
#  1              1053_at   9.445521
#  2               117_at   6.907440
#  3               121_at   8.797873
#  4            1255_g_at   3.980460
#  ...                ...        ...
#  22278   AFFX-ThrX-5_at   6.053002
#  22279   AFFX-ThrX-M_at   4.989706
#  22280  AFFX-TrpnX-3_at   0.460746
#  22281  AFFX-TrpnX-5_at   4.646841
#  22282  AFFX-TrpnX-M_at   1.400983
#
#  [22283 rows x 2 columns],
#  'GSM177970':                 ID_REF      VALUE
#  0            1007_s_at  11.684408
#  1              1053_at   9.680037
#  2               117_at   7.252752
#  3               121_at   9.744282
#  4            1255_g_at   6.728219
#  ...                ...        ...
#  22278   AFFX-ThrX-5_at   2.700673
#  22279   AFFX-ThrX-M_at   3.084962
#  22280  AFFX-TrpnX-3_at   1.607390
#  22281  AFFX-TrpnX-5_at   4.203870
#  22282  AFFX-TrpnX-M_at   2.860141
#
#  [22283 rows x 2 columns],
#  'GSM177971':                 ID_REF      VALUE
#  0            1007_s_at  10.925765
#  1              1053_at   8.820348
#  2               117_at   8.298393
#  3               121_at   9.676335
#  4            1255_g_at   5.154535
#  ...                ...        ...
#  22278   AFFX-ThrX-5_at   4.072628
#  22279   AFFX-ThrX-M_at   4.749027
#  22280  AFFX-TrpnX-3_at   2.293869
#  22281  AFFX-TrpnX-5_at   2.597958
#  22282  AFFX-TrpnX-M_at   2.702949
#
#  [22283 rows x 2 columns],
#  'GSM177972':                 ID_REF      VALUE
#  0            1007_s_at  11.383909
#  1              1053_at   8.055587
#  2               117_at   6.461278
#  3               121_at   9.680967
#  4            1255_g_at   5.867765
#  ...                ...        ...
#  22278   AFFX-ThrX-5_at   4.429224
#  22279   AFFX-ThrX-M_at   2.634894
#  22280  AFFX-TrpnX-3_at   5.029540
#  22281  AFFX-TrpnX-5_at   6.679533
#  22282  AFFX-TrpnX-M_at   1.618017
#
#  [22283 rows x 2 columns],
#  'GSM177973':                 ID_REF      VALUE
#  0            1007_s_at  12.196928
#  1              1053_at   9.377260
#  2               117_at   6.697262
#  3               121_at   9.597166
#  4            1255_g_at   3.660750
#  ...                ...        ...
#  22278   AFFX-ThrX-5_at   3.332840
#  22279   AFFX-ThrX-M_at   1.440502
#  22280  AFFX-TrpnX-3_at   1.649345
#  22281  AFFX-TrpnX-5_at   2.497353
#  22282  AFFX-TrpnX-M_at   1.659100
#
#  [22283 rows x 2 columns],
#  'GSM177974':                 ID_REF      VALUE
#  0            1007_s_at  12.077208
#  1              1053_at   8.220331
#  2               117_at   7.012698
#  3               121_at   9.371087
#  4            1255_g_at   2.270182
#  ...                ...        ...
#  22278   AFFX-ThrX-5_at   2.272845
#  22279   AFFX-ThrX-M_at   2.514271
#  22280  AFFX-TrpnX-3_at   0.789317
#  22281  AFFX-TrpnX-5_at   5.623977
#  22282  AFFX-TrpnX-M_at   2.436306
#
#  [22283 rows x 2 columns],
#  'GSM177975':                 ID_REF      VALUE
#  0            1007_s_at  10.790728
#  1              1053_at   8.285849
#  2               117_at   7.724798
#  3               121_at   9.279064
#  4            1255_g_at   5.819540
#  ...                ...        ...
#  22278   AFFX-ThrX-5_at   4.918681
#  22279   AFFX-ThrX-M_at   2.705918
#  22280  AFFX-TrpnX-3_at   1.272618
#  22281  AFFX-TrpnX-5_at   5.006015
#  22282  AFFX-TrpnX-M_at   2.266369
#
#  [22283 rows x 2 columns],
#  'GSM177976':                 ID_REF      VALUE
#  0            1007_s_at  11.348070
#  1              1053_at   8.490131
#  2               117_at   7.469120
#  3               121_at   8.848197
#  4            1255_g_at   5.026583
#  ...                ...        ...
#  22278   AFFX-ThrX-5_at   3.248179
#  22279   AFFX-ThrX-M_at   3.230570
#  22280  AFFX-TrpnX-3_at   2.608142
#  22281  AFFX-TrpnX-5_at   4.895339
#  22282  AFFX-TrpnX-M_at   0.777136
#
#  [22283 rows x 2 columns],
#  'GSM177977':                 ID_REF      VALUE
#  0            1007_s_at  10.765074
#  1              1053_at   9.076004
#  2               117_at   7.521836
#  3               121_at   9.574180
#  4            1255_g_at   4.069027
#  ...                ...        ...
#  22278   AFFX-ThrX-5_at   3.312015
#  22279   AFFX-ThrX-M_at   3.665628
#  22280  AFFX-TrpnX-3_at   2.890980
#  22281  AFFX-TrpnX-5_at   5.369573
#  22282  AFFX-TrpnX-M_at   2.342504
#
#  [22283 rows x 2 columns],
#  'GSM177978':                 ID_REF      VALUE
#  0            1007_s_at  10.954097
#  1              1053_at   8.617238
#  2               117_at   7.665971
#  3               121_at   9.530300
#  4            1255_g_at   6.233966
#  ...                ...        ...
#  22278   AFFX-ThrX-5_at   3.768767
#  22279   AFFX-ThrX-M_at   3.701752
#  22280  AFFX-TrpnX-3_at   5.610966
#  22281  AFFX-TrpnX-5_at   4.750645
#  22282  AFFX-TrpnX-M_at   3.689858
#
#  [22283 rows x 2 columns],
#  'GSM177979':                 ID_REF      VALUE
#  0            1007_s_at  10.699189
#  1              1053_at   9.105598
#  2               117_at   7.872596
#  3               121_at   8.809434
#  4            1255_g_at   5.887243
#  ...                ...        ...
#  22278   AFFX-ThrX-5_at   3.546393
#  22279   AFFX-ThrX-M_at   5.603872
#  22280  AFFX-TrpnX-3_at   3.051439
#  22281  AFFX-TrpnX-5_at   3.734064
#  22282  AFFX-TrpnX-M_at   2.270799
#
#  [22283 rows x 2 columns],
#  'GSM177980':                 ID_REF      VALUE
#  0            1007_s_at  11.847212
#  1              1053_at   8.486396
#  2               117_at   6.880491
#  3               121_at   9.337326
#  4            1255_g_at   6.262152
#  ...                ...        ...
#  22278   AFFX-ThrX-5_at   3.992804
#  22279   AFFX-ThrX-M_at   3.678619
#  22280  AFFX-TrpnX-3_at   1.775790
#  22281  AFFX-TrpnX-5_at   3.547980
#  22282  AFFX-TrpnX-M_at   2.581747
#
#  [22283 rows x 2 columns],
#  'GSM177981':                 ID_REF      VALUE
#  0            1007_s_at  12.336336
#  1              1053_at   8.748898
#  2               117_at   5.659256
#  3               121_at   9.045372
#  4            1255_g_at   5.846328
#  ...                ...        ...
#  22278   AFFX-ThrX-5_at   4.096091
#  22279   AFFX-ThrX-M_at   3.834405
#  22280  AFFX-TrpnX-3_at   6.005744
#  22281  AFFX-TrpnX-5_at   3.413078
#  22282  AFFX-TrpnX-M_at   3.605710
#
#  [22283 rows x 2 columns],
#  'GSM177982':                 ID_REF      VALUE
#  0            1007_s_at  11.267636
#  1              1053_at   8.962499
#  2               117_at   6.183324
#  3               121_at   8.632369
#  4            1255_g_at   2.987526
#  ...                ...        ...
#  22278   AFFX-ThrX-5_at   2.173404
#  22279   AFFX-ThrX-M_at   1.585049
#  22280  AFFX-TrpnX-3_at   1.071707
#  22281  AFFX-TrpnX-5_at   3.476371
#  22282  AFFX-TrpnX-M_at   1.768406
#
#  [22283 rows x 2 columns],
#  'GSM177983':                 ID_REF      VALUE
#  0            1007_s_at  11.593156
#  1              1053_at   7.913387
#  2               117_at   7.609764
#  3               121_at   9.232701
#  4            1255_g_at   5.821092
#  ...                ...        ...
#  22278   AFFX-ThrX-5_at   4.010481
#  22279   AFFX-ThrX-M_at   4.906193
#  22280  AFFX-TrpnX-3_at   1.016547
#  22281  AFFX-TrpnX-5_at   3.853516
#  22282  AFFX-TrpnX-M_at   2.303786
#
#  [22283 rows x 2 columns],
#  'GSM177984':                 ID_REF      VALUE
#  0            1007_s_at  11.830718
#  1              1053_at   8.684773
#  2               117_at   6.908828
#  3               121_at   8.671011
#  4            1255_g_at   3.215237
#  ...                ...        ...
#  22278   AFFX-ThrX-5_at   4.296991
#  22279   AFFX-ThrX-M_at   2.455983
#  22280  AFFX-TrpnX-3_at   1.786566
#  22281  AFFX-TrpnX-5_at   2.484210
#  22282  AFFX-TrpnX-M_at   1.418776
#
#  [22283 rows x 2 columns],
#  'GSM177985':                 ID_REF      VALUE
#  0            1007_s_at  10.819729
#  1              1053_at   8.271713
#  2               117_at   7.868753
#  3               121_at   8.998454
#  4            1255_g_at   4.849244
#  ...                ...        ...
#  22278   AFFX-ThrX-5_at   3.667279
#  22279   AFFX-ThrX-M_at   2.462085
#  22280  AFFX-TrpnX-3_at   2.746585
#  22281  AFFX-TrpnX-5_at   5.586098
#  22282  AFFX-TrpnX-M_at   2.010202
#
#  [22283 rows x 2 columns],
#  'GSM177986':                 ID_REF      VALUE
#  0            1007_s_at  11.303773
#  1              1053_at   8.265806
#  2               117_at   5.876970
#  3               121_at   9.365496
#  4            1255_g_at   6.134290
#  ...                ...        ...
#  22278   AFFX-ThrX-5_at   3.248853
#  22279   AFFX-ThrX-M_at   4.014986
#  22280  AFFX-TrpnX-3_at   1.738409
#  22281  AFFX-TrpnX-5_at   5.706132
#  22282  AFFX-TrpnX-M_at   2.618657
#
#  [22283 rows x 2 columns],
#  'GSM177987':                 ID_REF      VALUE
#  0            1007_s_at  11.353727
#  1              1053_at   7.813577
#  2               117_at   7.655158
#  3               121_at   9.463337
#  4            1255_g_at   6.118549
#  ...                ...        ...
#  22278   AFFX-ThrX-5_at   3.476389
#  22279   AFFX-ThrX-M_at   2.528194
#  22280  AFFX-TrpnX-3_at   1.179861
#  22281  AFFX-TrpnX-5_at   3.804838
#  22282  AFFX-TrpnX-M_at   3.195706
#
#  [22283 rows x 2 columns],
#  'GSM177988':                 ID_REF     VALUE
#  0            1007_s_at  9.539296
#  1              1053_at  8.761100
#  2               117_at  6.709205
#  3               121_at  8.797212
#  4            1255_g_at  4.083929
#  ...                ...       ...
#  22278   AFFX-ThrX-5_at  2.915861
#  22279   AFFX-ThrX-M_at  5.848090
#  22280  AFFX-TrpnX-3_at  1.730377
#  22281  AFFX-TrpnX-5_at  4.200246
#  22282  AFFX-TrpnX-M_at  1.738761
#
# ...
#  3               121_at   9.470694
#  4            1255_g_at   6.965989
#  ...                ...        ...
#  22278   AFFX-ThrX-5_at   4.877751
#  22279   AFFX-ThrX-M_at   2.588481
#  22280  AFFX-TrpnX-3_at   5.653282
#  22281  AFFX-TrpnX-5_at   5.871858
#  22282  AFFX-TrpnX-M_at   3.376172
#
#  [22283 rows x 2 columns],
#  'GSM178049':                 ID_REF      VALUE
#  0            1007_s_at  11.174763
#  1              1053_at   9.025710
#  2               117_at   7.767599
#  3               121_at   9.675564
#  4            1255_g_at   5.855386
#  ...                ...        ...
#  22278   AFFX-ThrX-5_at   3.186712
#  22279   AFFX-ThrX-M_at   3.211232
#  22280  AFFX-TrpnX-3_at   2.039100
#  22281  AFFX-TrpnX-5_at   3.614430
#  22282  AFFX-TrpnX-M_at   1.923005
#
#  [22283 rows x 2 columns],
#  'GSM178050':                 ID_REF      VALUE
#  0            1007_s_at  11.133137
#  1              1053_at   9.472104
#  2               117_at   7.857802
#  3               121_at   9.517830
#  4            1255_g_at   5.964271
#  ...                ...        ...
#  22278   AFFX-ThrX-5_at   1.533743
#  22279   AFFX-ThrX-M_at   1.983324
#  22280  AFFX-TrpnX-3_at   2.472052
#  22281  AFFX-TrpnX-5_at   3.574819
#  22282  AFFX-TrpnX-M_at   3.206669
#
#  [22283 rows x 2 columns],
#  'GSM178051':                 ID_REF      VALUE
#  0            1007_s_at  11.292254
#  1              1053_at   8.714159
#  2               117_at   7.275424
#  3               121_at   9.566235
#  4            1255_g_at   4.872508
#  ...                ...        ...
#  22278   AFFX-ThrX-5_at   5.937375
#  22279   AFFX-ThrX-M_at   5.204098
#  22280  AFFX-TrpnX-3_at   2.104510
#  22281  AFFX-TrpnX-5_at   3.354306
#  22282  AFFX-TrpnX-M_at   1.779394
#
#  [22283 rows x 2 columns],
#  'GSM178052':                 ID_REF      VALUE
#  0            1007_s_at  11.440696
#  1              1053_at   8.387691
#  2               117_at   7.041790
#  3               121_at   9.327067
#  4            1255_g_at   3.218034
#  ...                ...        ...
#  22278   AFFX-ThrX-5_at   3.226363
#  22279   AFFX-ThrX-M_at   2.778250
#  22280  AFFX-TrpnX-3_at   4.963371
#  22281  AFFX-TrpnX-5_at   5.541678
#  22282  AFFX-TrpnX-M_at   2.291168
#
#  [22283 rows x 2 columns],
#  'GSM178053':                 ID_REF      VALUE
#  0            1007_s_at  11.636993
#  1              1053_at   8.749036
#  2               117_at   7.402392
#  3               121_at  10.143014
#  4            1255_g_at   6.733908
#  ...                ...        ...
#  22278   AFFX-ThrX-5_at   5.613946
#  22279   AFFX-ThrX-M_at   3.522884
#  22280  AFFX-TrpnX-3_at   2.635869
#  22281  AFFX-TrpnX-5_at   4.309366
#  22282  AFFX-TrpnX-M_at   3.048195
#
#  [22283 rows x 2 columns],
#  'GSM178054':                 ID_REF      VALUE
#  0            1007_s_at  10.602644
#  1              1053_at   8.274103
#  2               117_at   6.821103
#  3               121_at   8.913220
#  4            1255_g_at   3.186679
#  ...                ...        ...
#  22278   AFFX-ThrX-5_at   4.024850
#  22279   AFFX-ThrX-M_at   2.407047
#  22280  AFFX-TrpnX-3_at   3.862048
#  22281  AFFX-TrpnX-5_at   5.441735
#  22282  AFFX-TrpnX-M_at   1.565150
#
#  [22283 rows x 2 columns],
#  'GSM178055':                 ID_REF     VALUE
#  0            1007_s_at  8.844147
#  1              1053_at  9.667538
#  2               117_at  7.454183
#  3               121_at  9.241880
#  4            1255_g_at  5.086456
#  ...                ...       ...
#  22278   AFFX-ThrX-5_at  2.804214
#  22279   AFFX-ThrX-M_at  2.923281
#  22280  AFFX-TrpnX-3_at  0.512028
#  22281  AFFX-TrpnX-5_at  3.295130
#  22282  AFFX-TrpnX-M_at  1.690331
#
#  [22283 rows x 2 columns],
#  'GSM178056':                 ID_REF      VALUE
#  0            1007_s_at  11.455134
#  1              1053_at   9.264726
#  2               117_at   7.148635
#  3               121_at   9.130453
#  4            1255_g_at   4.965042
#  ...                ...        ...
#  22278   AFFX-ThrX-5_at   4.254416
#  22279   AFFX-ThrX-M_at   5.179465
#  22280  AFFX-TrpnX-3_at   3.348497
#  22281  AFFX-TrpnX-5_at   4.220033
#  22282  AFFX-TrpnX-M_at   1.752312
#
#  [22283 rows x 2 columns],
#  'GSM178057':                 ID_REF      VALUE
#  0            1007_s_at  10.732961
#  1              1053_at   9.191227
#  2               117_at   7.766587
#  3               121_at   9.025727
#  4            1255_g_at   4.046647
#  ...                ...        ...
#  22278   AFFX-ThrX-5_at   1.857498
#  22279   AFFX-ThrX-M_at   3.636763
#  22280  AFFX-TrpnX-3_at   1.836341
#  22281  AFFX-TrpnX-5_at   4.610084
#  22282  AFFX-TrpnX-M_at   2.471317
#
#  [22283 rows x 2 columns],
#  'GSM178058':                 ID_REF      VALUE
#  0            1007_s_at  11.031153
#  1              1053_at   9.781526
#  2               117_at   6.360104
#  3               121_at   9.148399
#  4            1255_g_at   5.789059
#  ...                ...        ...
#  22278   AFFX-ThrX-5_at   4.431863
#  22279   AFFX-ThrX-M_at   2.646006
#  22280  AFFX-TrpnX-3_at   2.259534
#  22281  AFFX-TrpnX-5_at   2.720979
#  22282  AFFX-TrpnX-M_at   1.769852
#
#  [22283 rows x 2 columns],
#  'GSM178059':                 ID_REF     VALUE
#  0            1007_s_at  9.563122
#  1              1053_at  9.542469
#  2               117_at  9.124972
#  3               121_at  8.960171
#  4            1255_g_at  4.244160
#  ...                ...       ...
#  22278   AFFX-ThrX-5_at  4.565712
#  22279   AFFX-ThrX-M_at  2.863712
#  22280  AFFX-TrpnX-3_at  1.692130
#  22281  AFFX-TrpnX-5_at  5.744539
#  22282  AFFX-TrpnX-M_at  2.690968
#
#  [22283 rows x 2 columns],
#  'GSM178060':                 ID_REF      VALUE
#  0            1007_s_at  11.063596
#  1              1053_at   9.287463
#  2               117_at   6.454418
#  3               121_at   9.632744
#  4            1255_g_at   2.367696
#  ...                ...        ...
#  22278   AFFX-ThrX-5_at   3.898164
#  22279   AFFX-ThrX-M_at   2.035824
#  22280  AFFX-TrpnX-3_at   4.565481
#  22281  AFFX-TrpnX-5_at   5.267646
#  22282  AFFX-TrpnX-M_at   2.144820
#
#  [22283 rows x 2 columns],
#  'GSM178061':                 ID_REF      VALUE
#  0            1007_s_at  11.642393
#  1              1053_at   8.911592
#  2               117_at   6.261898
#  3               121_at   9.516010
#  4            1255_g_at   4.970484
#  ...                ...        ...
#  22278   AFFX-ThrX-5_at   3.044273
#  22279   AFFX-ThrX-M_at   1.765618
#  22280  AFFX-TrpnX-3_at   1.928578
#  22281  AFFX-TrpnX-5_at   3.023824
#  22282  AFFX-TrpnX-M_at   2.206804
#
#  [22283 rows x 2 columns],
#  'GSM178062':                 ID_REF      VALUE
#  0            1007_s_at  11.626936
#  1              1053_at   8.537798
#  2               117_at   6.822776
#  3               121_at   9.735808
#  4            1255_g_at   5.511114
#  ...                ...        ...
#  22278   AFFX-ThrX-5_at   2.950040
#  22279   AFFX-ThrX-M_at   3.425053
#  22280  AFFX-TrpnX-3_at   1.856879
#  22281  AFFX-TrpnX-5_at   3.641553
#  22282  AFFX-TrpnX-M_at   2.434110
#
#  [22283 rows x 2 columns],
#  'GSM178063':                 ID_REF      VALUE
#  0            1007_s_at  10.828316
#  1              1053_at   9.527984
#  2               117_at   6.640706
#  3               121_at   8.854952
#  4            1255_g_at   5.238263
#  ...                ...        ...
#  22278   AFFX-ThrX-5_at   1.986084
#  22279   AFFX-ThrX-M_at   4.862652
#  22280  AFFX-TrpnX-3_at   1.729300
#  22281  AFFX-TrpnX-5_at   2.938388
#  22282  AFFX-TrpnX-M_at   1.740175
#
#  [22283 rows x 2 columns],
#  'GSM178064':                 ID_REF      VALUE
#  0            1007_s_at  11.970571
#  1              1053_at   9.325652
#  2               117_at   6.860208
#  3               121_at   9.278947
#  4            1255_g_at   4.930840
#  ...                ...        ...
#  22278   AFFX-ThrX-5_at   2.661273
#  22279   AFFX-ThrX-M_at   2.864016
#  22280  AFFX-TrpnX-3_at   1.730501
#  22281  AFFX-TrpnX-5_at   3.790459
#  22282  AFFX-TrpnX-M_at   1.912592
#
#  [22283 rows x 2 columns],
#  'GSM178065':                 ID_REF      VALUE
#  0            1007_s_at  11.109733
#  1              1053_at   8.995905
#  2               117_at   8.294984
#  3               121_at   9.772874
#  4            1255_g_at   6.247559
#  ...                ...        ...
#  22278   AFFX-ThrX-5_at   4.039750
#  22279   AFFX-ThrX-M_at   4.411973
#  22280  AFFX-TrpnX-3_at   1.922153
#  22281  AFFX-TrpnX-5_at   4.440314
#  22282  AFFX-TrpnX-M_at   2.048591
#
#  [22283 rows x 2 columns],
#  'GSM178066':                 ID_REF      VALUE
#  0            1007_s_at  11.290319
#  1              1053_at   8.181944
#  2               117_at   7.773742
#  3               121_at   9.056040
#  4            1255_g_at   6.312816
#  ...                ...        ...
#  22278   AFFX-ThrX-5_at   2.235160
#  22279   AFFX-ThrX-M_at   2.501476
#  22280  AFFX-TrpnX-3_at   2.502374
#  22281  AFFX-TrpnX-5_at   2.038959
#  22282  AFFX-TrpnX-M_at   1.608721
#
#  [22283 rows x 2 columns],
#  'GSM178067':                 ID_REF      VALUE
#  0            1007_s_at  10.606586
#  1              1053_at   7.776818
#  2               117_at   6.479633
#  3               121_at   9.230816
#  4            1255_g_at   2.627601
#  ...                ...        ...
#  22278   AFFX-ThrX-5_at   5.082831
#  22279   AFFX-ThrX-M_at   5.903278
#  22280  AFFX-TrpnX-3_at   2.265440
#  22281  AFFX-TrpnX-5_at   2.872448
#  22282  AFFX-TrpnX-M_at   3.484999
#
#  [22283 rows x 2 columns],
#  'GSM178068':                 ID_REF      VALUE
#  0            1007_s_at  10.883727
#  1              1053_at   9.364232
#  2               117_at   6.427030
#  3               121_at   9.322600
#  4            1255_g_at   3.018034
#  ...                ...        ...
#  22278   AFFX-ThrX-5_at   3.082999
#  22279   AFFX-ThrX-M_at   3.353726
#  22280  AFFX-TrpnX-3_at   1.501817
#  22281  AFFX-TrpnX-5_at   5.591270
#  22282  AFFX-TrpnX-M_at   2.250598
#
#  [22283 rows x 2 columns],
#  'GSM178069':                 ID_REF      VALUE
#  0            1007_s_at  11.147540
#  1              1053_at   8.557268
#  2               117_at   7.598189
#  3               121_at   9.628801
#  4            1255_g_at   6.344045
#  ...                ...        ...
#  22278   AFFX-ThrX-5_at   3.775764
#  22279   AFFX-ThrX-M_at   3.646039
#  22280  AFFX-TrpnX-3_at   2.638657
#  22281  AFFX-TrpnX-5_at   3.487385
#  22282  AFFX-TrpnX-M_at   1.927904
#
#  [22283 rows x 2 columns],
#  'GSM178070':                 ID_REF      VALUE
#  0            1007_s_at  11.973257
#  1              1053_at   8.549942
#  2               117_at   5.428693
#  3               121_at   9.642593
#  4            1255_g_at   4.987768
#  ...                ...        ...
#  22278   AFFX-ThrX-5_at   3.689672
#  22279   AFFX-ThrX-M_at   3.828991
#  22280  AFFX-TrpnX-3_at   2.037268
#  22281  AFFX-TrpnX-5_at   5.457531
#  22282  AFFX-TrpnX-M_at   1.779694
#
#  [22283 rows x 2 columns],
#  'GSM178071':                 ID_REF      VALUE
#  0            1007_s_at  11.175211
#  1              1053_at   8.384553
#  2               117_at   6.904753
#  3               121_at   9.227480
#  4            1255_g_at   4.528342
#  ...                ...        ...
#  22278   AFFX-ThrX-5_at   2.368027
#  22279   AFFX-ThrX-M_at   3.400739
#  22280  AFFX-TrpnX-3_at   3.002210
#  22281  AFFX-TrpnX-5_at   5.494877
#  22282  AFFX-TrpnX-M_at   1.572536
#
#  [22283 rows x 2 columns],
#  'GSM178072':                 ID_REF      VALUE
#  0            1007_s_at  10.651727
#  1              1053_at   9.305704
#  2               117_at   6.382287
#  3               121_at   9.248429
#  4            1255_g_at   4.244975
#  ...                ...        ...
#  22278   AFFX-ThrX-5_at   2.878628
#  22279   AFFX-ThrX-M_at   4.718294
#  22280  AFFX-TrpnX-3_at   5.072859
#  22281  AFFX-TrpnX-5_at   5.621310
#  22282  AFFX-TrpnX-M_at   2.763369
#
#  [22283 rows x 2 columns],
#  'GSM178073':                 ID_REF      VALUE
#  0            1007_s_at  11.626131
#  1              1053_at   9.252529
#  2               117_at   7.534337
#  3               121_at   8.949350
#  4            1255_g_at   3.653802
#  ...                ...        ...
#  22278   AFFX-ThrX-5_at   3.315229
#  22279   AFFX-ThrX-M_at   3.400638
#  22280  AFFX-TrpnX-3_at   3.254034
#  22281  AFFX-TrpnX-5_at   2.985075
#  22282  AFFX-TrpnX-M_at   2.523490
#
#  [22283 rows x 2 columns],
#  'GSM178074':                 ID_REF      VALUE
#  0            1007_s_at  12.095386
#  1              1053_at   8.594601
#  2               117_at   7.973816
#  3               121_at   9.265321
#  4            1255_g_at   5.337356
#  ...                ...        ...
#  22278   AFFX-ThrX-5_at   3.002246
#  22279   AFFX-ThrX-M_at   1.624498
#  22280  AFFX-TrpnX-3_at   5.201070
#  22281  AFFX-TrpnX-5_at   1.985025
#  22282  AFFX-TrpnX-M_at   1.794379
#
#  [22283 rows x 2 columns],
#  'GSM178075':                 ID_REF      VALUE
#  0            1007_s_at  10.818799
#  1              1053_at   9.372028
#  2               117_at   7.052388
#  3               121_at   9.373517
#  4            1255_g_at   5.524546
#  ...                ...        ...
#  22278   AFFX-ThrX-5_at   2.775177
#  22279   AFFX-ThrX-M_at   6.247997
#  22280  AFFX-TrpnX-3_at   1.566979
#  22281  AFFX-TrpnX-5_at   2.898079
#  22282  AFFX-TrpnX-M_at   2.754495
#
#  [22283 rows x 2 columns],
#  'GSM178076':                 ID_REF      VALUE
#  0            1007_s_at  10.649233
#  1              1053_at   8.846761
#  2               117_at   7.072636
#  3               121_at   8.685993
#  4            1255_g_at   5.887738
#  ...                ...        ...
#  22278   AFFX-ThrX-5_at   1.804964
#  22279   AFFX-ThrX-M_at   3.568859
#  22280  AFFX-TrpnX-3_at   2.107088
#  22281  AFFX-TrpnX-5_at   2.804893
#  22282  AFFX-TrpnX-M_at   1.552359
#
#  [22283 rows x 2 columns],
#  'GSM178077':                 ID_REF      VALUE
#  0            1007_s_at  10.619263
#  1              1053_at   8.639552
#  2               117_at   6.240142
#  3               121_at   9.227666
#  4            1255_g_at   5.316872
#  ...                ...        ...
#  22278   AFFX-ThrX-5_at   3.200786
#  22279   AFFX-ThrX-M_at   5.336106
#  22280  AFFX-TrpnX-3_at   1.059342
#  22281  AFFX-TrpnX-5_at   5.234032
#  22282  AFFX-TrpnX-M_at   2.281197
#
#  [22283 rows x 2 columns],
#  'GSM178078':                 ID_REF      VALUE
#  0            1007_s_at  10.785023
#  1              1053_at  10.012078
#  2               117_at   6.855161
#  3               121_at   8.987488
#  4            1255_g_at   5.833270
#  ...                ...        ...
#  22278   AFFX-ThrX-5_at   3.553865
#  22279   AFFX-ThrX-M_at   5.375497
#  22280  AFFX-TrpnX-3_at   0.929578
#  22281  AFFX-TrpnX-5_at   2.431918
#  22282  AFFX-TrpnX-M_at   3.235379
#
#  [22283 rows x 2 columns],
#  'GSM178079':                 ID_REF      VALUE
#  0            1007_s_at  11.390198
#  1              1053_at   9.830344
#  2               117_at   7.150656
#  3               121_at   8.766830
#  4            1255_g_at   3.977743
#  ...                ...        ...
#  22278   AFFX-ThrX-5_at   2.859465
#  22279   AFFX-ThrX-M_at   1.858311
#  22280  AFFX-TrpnX-3_at   1.906231
#  22281  AFFX-TrpnX-5_at   4.948435
#  22282  AFFX-TrpnX-M_at   2.761732
#
#  [22283 rows x 2 columns],
#  'GSM178080':                 ID_REF      VALUE
#  0            1007_s_at  10.735085
#  1              1053_at   8.894038
#  2               117_at   7.262618
#  3               121_at   9.064142
#  4            1255_g_at   3.781916
#  ...                ...        ...
#  22278   AFFX-ThrX-5_at   5.588937
#  22279   AFFX-ThrX-M_at   4.302067
#  22280  AFFX-TrpnX-3_at   4.468821
#  22281  AFFX-TrpnX-5_at   5.678535
#  22282  AFFX-TrpnX-M_at   3.143182
#
#  [22283 rows x 2 columns],
#  'GSM178081':                 ID_REF      VALUE
#  0            1007_s_at  10.653104
#  1              1053_at   8.854766
#  2               117_at   6.636791
#  3               121_at   9.283177
#  4            1255_g_at   3.724769
#  ...                ...        ...
#  22278   AFFX-ThrX-5_at   3.120619
#  22279   AFFX-ThrX-M_at   5.088536
#  22280  AFFX-TrpnX-3_at   5.682201
#  22281  AFFX-TrpnX-5_at   3.685063
#  22282  AFFX-TrpnX-M_at   1.916516
#
#  [22283 rows x 2 columns],
#  'GSM178082':                 ID_REF      VALUE
#  0            1007_s_at  11.310992
#  1              1053_at   9.674872
#  2               117_at   7.276915
#  3               121_at   9.646810
#  4            1255_g_at   4.854293
#  ...                ...        ...
#  22278   AFFX-ThrX-5_at   3.727378
#  22279   AFFX-ThrX-M_at   2.742265
#  22280  AFFX-TrpnX-3_at   2.349358
#  22281  AFFX-TrpnX-5_at   1.658981
#  22282  AFFX-TrpnX-M_at   1.403235
#
#  [22283 rows x 2 columns]}

# %%
df = []
for name in gsms.keys():
    d = dict(zip(genes[name]['ID_REF'],genes[name]['VALUE']))
    d.update(dict([x.split(':') for x in gsms[name]]))
    df += [d]

# %%
df = pd.DataFrame(df)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 198 entries, 0 to 197
# Columns: 22310 entries, 1007_s_at to veridex_risk
# dtypes: float64(22283), object(27)
# memory usage: 33.7+ MB

# %%
df.to_csv("cleaned_data.csv")

# %% [markdown]
# ### Selecting only certain rows

# %%
df = pd.read_csv("cleaned_data.csv")
# Out:
# /home/adit/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3147: DtypeWarning: Columns (22285,22291,22292,22295,22305,22306,22307) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df['e.os'].value_counts()
# Out:
# 0    142
# 1     56
# Name: e.os, dtype: int64

# %%
gene = pd.read_csv("gene.csv")

# %%
relevant_genes = gene["Gene"].values

# %%
df.columns[-28:]
# Out:
# Index(['AFFX-TrpnX-M_at', 'samplename', 'id', 'filename', 'hospital', 'age',
#        'size', 'Surgery_type', 'Histtype', 'Angioinv', 'Lymp_infil', 'node',
#        'grade', 'er', 't.rfs', 'e.rfs', 't.os', 'e.os', 't.dmfs', 'e.dmfs',
#        't.tdm', 'e.tdm', 'risksg', 'NPI', 'risknpi', 'AOL_os_10y', 'risk_AOL',
#        'veridex_risk'],
#       dtype='object')

# %%
selected = df[list(relevant_genes) + ['samplename', 'id', 'filename', 'hospital', 'age',
       'size', 'Surgery_type', 'Histtype', 'Angioinv', 'Lymp_infil', 'node',
       'grade', 'er', 't.rfs', 'e.rfs', 't.os', 'e.os', 't.dmfs', 'e.dmfs',
       't.tdm', 'e.tdm', 'risksg', 'NPI', 'risknpi', 'AOL_os_10y', 'risk_AOL',
       'veridex_risk']]

# %%
selected.to_csv("selected.csv")

# %%
selected['t.dmfs'] > selected['t.tdm']
# Out:
# 0       723
# 1      6591
# 2       524
# 3      6255
# 4      3822
#        ...
# 193    5673
# 194     404
# 195    2225
# 196    2722
# 197    1781
# Name: t.dmfs, Length: 198, dtype: int64
