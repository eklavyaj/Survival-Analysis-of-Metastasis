# %%
# !pip install GEOparse
# Out:
# ...
#      |████████████████████████████████| 278 kB 1.8 MB/s eta 0:00:01
# ...
#   Created wheel for GEOparse: filename=GEOparse-2.0.3-py3-none-any.whl size=29032 sha256=5f3ede31684474614f7db3d4cc768814081f9aa461a47fec3a793faa683685b5
#   Stored in directory: /home/adit/.cache/pip/wheels/4d/15/e8/fbf3b47444215d9728c20d7b35436b50086aa67c2ad6dcedad
# Successfully built GEOparse
# ...
# WARNING: You are using pip version 20.0.2; however, version 21.2.4 is available.
# You should consider upgrading via the '/home/adit/anaconda3/bin/python -m pip install --upgrade pip' command.

# %%
import GEOparse
import pandas as pd

# %%
gse = GEOparse.get_GEO(filepath="./GSE7390_family.soft.gz",silent=True,)

# %%
print()
print("GSM example:")
for gsm_name, gsm in gse.gsms.items():
    print("Name: ", gsm_name)
    print("Metadata:",)
    for key, value in gsm.metadata.items():
        print(" - %s : %s" % (key, ", ".join(value)))
    print ("Table data:",)
    print (gsm.table.tail())
    break

print()
print("GPL example:")
for gpl_name, gpl in gse.gpls.items():
    print("Name: ", gpl_name)
    print("Metadata:",)
    for key, value in gpl.metadata.items():
        print(" - %s : %s" % (key, ", ".join(value)))
    print("Table data:",)
    print(gpl.table.head())
    break
# Out:
# GSM example:
# Name:  GSM177885
# Metadata:
#  - title : VDXGUYU_4002
#  - geo_accession : GSM177885
#  - status : Public on Jun 11 2007
#  - submission_date : Mar 28 2007
#  - last_update_date : May 31 2013
#  - type : RNA
#  - channel_count : 1
#  - source_name_ch1 : VDXGUYU_4002
#  - organism_ch1 : Homo sapiens
#  - taxid_ch1 : 9606
#  - characteristics_ch1 : samplename: VDXGUYU_4002, id: 4002, filename: 10-4002_GUYA.CEL.gz, hospital: GUY, age: 57, size: 3, Surgery_type: 0, Histtype: 1, Angioinv: 1, Lymp_infil: 2, node: 0, grade: 3, er: 0, t.rfs: 723, e.rfs: 1, t.os: 937, e.os: 1, t.dmfs: 723, e.dmfs: 1, t.tdm: 723, e.tdm: 1, risksg: 2, NPI: 4.6, risknpi: 2, AOL_os_10y: 62.7, risk_AOL: 1, veridex_risk: Poor
#  - molecule_ch1 : total RNA
# ...

# %%
gse.gsms['GPL96'].columns
# Out:
#                                                                         description
# ID                                Affymetrix Probe Set ID LINK_PRE:"https://www....
# GB_ACC                            GenBank Accession Number LINK_PRE:"http://www....
# SPOT_ID                                                         identifies controls
# Species Scientific Name           The genus and species of the organism represen...
# Annotation Date                   The date that the annotations for this probe a...
# Sequence Type
# Sequence Source                   The database from which the sequence used to d...
# Target Description
# Representative Public ID          The accession number of a representative seque...
# Gene Title                              Title of Gene represented by the probe set.
# Gene Symbol                       A gene symbol, when one is available (from Uni...
# ENTREZ_GENE_ID                    Entrez Gene Database UID LINK_PRE:"http://www....
# ...

# %%
gse.gsms['GSM177885'].metadata['characteristics_ch1']#.GPL96
# Out:
# ['samplename: VDXGUYU_4002',
#  'id: 4002',
#  'filename: 10-4002_GUYA.CEL.gz',
#  'hospital: GUY',
#  'age: 57',
#  'size: 3',
#  'Surgery_type: 0',
#  'Histtype: 1',
#  'Angioinv: 1',
#  'Lymp_infil: 2',
#  'node: 0',
#  'grade: 3',
#  'er: 0',
#  't.rfs: 723',
#  'e.rfs: 1',
#  't.os: 937',
#  'e.os: 1',
#  't.dmfs: 723',
#  'e.dmfs: 1',
#  't.tdm: 723',
#  'e.tdm: 1',
#  'risksg: 2',
#  'NPI: 4.6',
#  'risknpi: 2',
#  'AOL_os_10y: 62.7',
#  'risk_AOL: 1',
#  'veridex_risk: Poor']

# %%
gse.gsms['GSM177885'].table#.data#['characteristics_ch1']#.GPL96
# Out:
#                 ID_REF      VALUE
# 0            1007_s_at  10.780787
# 1              1053_at   8.674201
# 2               117_at   7.738589
# 3               121_at   9.285511
# 4            1255_g_at   6.610484
# ...                ...        ...
# 22278   AFFX-ThrX-5_at   5.680176
# 22279   AFFX-ThrX-M_at   1.753631
# 22280  AFFX-TrpnX-3_at   2.223181
# 22281  AFFX-TrpnX-5_at   4.013873
# 22282  AFFX-TrpnX-M_at   1.603252
#
# [22283 rows x 2 columns]
